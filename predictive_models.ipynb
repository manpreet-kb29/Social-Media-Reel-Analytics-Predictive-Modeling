# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
df = pd.read_csv("youtube_shorts_tiktok_trends_2025.csv")

df.head()
# Out:
#   platform country   region language category     hashtag  \
# 0   TikTok      Jp     Asia       ja   Gaming  #Lifestyle
# 1   TikTok      Se   Europe       sv     Food     #Sports
# 2   TikTok      Za   Africa       en      Art    #Workout
# 3   TikTok      Kr     Asia       ko     News    #Esports
# 4   TikTok      Au  Oceania       en   Beauty     #Comedy
#
#                   title_keywords    author_handle sound_type     music_track  \
# 0        Night Routine — College       NextVision   trending       8bit loop
# 1      Morning Routine — College  DailyVlogsDiego   trending     Street vibe
# 2        Night Routine — College        BeyondHub   licensed     Gallery pad
# 3     Best Settings for Fortnite          NextHub   original   Neutral piano
# 4  When your friend is Beginners    LucasOfficial   licensed  Soft glam loop
#
#    ...  traffic_source  is_weekend                            row_id  \
# 0  ...        External           1  2e681528d17a1fe1986857942536ec27
# 1  ...          Search           0  2e35fa0b2978b9cae635839c1d4e9e74
# 2  ...        External           1  0d88a011235a82244995ef52961f9502
# 3  ...          Search           1  e15cff7621ed3f9eb9d2c97c841be0f3
# 4  ...          ForYou           1  d696b4f0a50ea70e7cb5021be7e198ec
#
#    engagement_total  like_rate  dislike_rate  engagement_per_1k  \
# 0             30317   0.086159      0.004004            120.069
# 1             30577   0.085298      0.002421            113.005
# 2               503   0.049154      0.001625             68.111
# 3              7828   0.086257      0.003164            108.156
# 4              1171   0.051441      0.001175             72.400
#
#    engagement_like_rate engagement_comment_rate engagement_share_rate
# 0              0.086159                0.012555              0.007830
# 1              0.085298                0.007850              0.007791
# 2              0.049154                0.004469              0.005146
# 3              0.086257                0.011205              0.005292
# 4              0.051441                0.004204              0.004142
#
# [5 rows x 58 columns]

# %%
print(df.shape)

df.info()
# Out:
# (48079, 58)
# <class 'pandas.DataFrame'>
# RangeIndex: 48079 entries, 0 to 48078
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   platform                 48079 non-null  str
#  1   country                  48079 non-null  str
#  2   region                   48079 non-null  str
#  3   language                 48079 non-null  str
#  4   category                 48079 non-null  str
#  5   hashtag                  48079 non-null  str
#  6   title_keywords           48079 non-null  str
#  7   author_handle            48079 non-null  str
#  8   sound_type               48079 non-null  str
#  9   music_track              48079 non-null  str
#  10  week_of_year             48079 non-null  int64
#  11  duration_sec             48079 non-null  int64
#  12  views                    48079 non-null  int64
#  13  likes                    48079 non-null  int64
#  14  comments                 48079 non-null  int64
#  15  shares                   48079 non-null  int64
#  16  saves                    48079 non-null  int64
#  17  engagement_rate          48079 non-null  float64
#  18  trend_label              48079 non-null  str
#  19  source_hint              48079 non-null  str
#  20  notes                    48079 non-null  str
#  21  device_type              48079 non-null  str
#  22  upload_hour              48079 non-null  int64
#  23  genre                    48079 non-null  str
#  24  trend_duration_days      48079 non-null  int64
#  25  trend_type               48079 non-null  str
#  26  engagement_velocity      48079 non-null  float64
#  27  dislikes                 48079 non-null  int64
#  28  comment_ratio            48079 non-null  float64
#  29  share_rate               48079 non-null  float64
#  30  save_rate                48079 non-null  float64
#  31  like_dislike_ratio       48079 non-null  float64
#  32  publish_dayofweek        48079 non-null  str
#  33  publish_period           48079 non-null  str
#  34  event_season             48079 non-null  str
#  35  tags                     48079 non-null  str
#  36  sample_comments          48079 non-null  str
#  37  creator_avg_views        48079 non-null  float64
#  38  creator_tier             48079 non-null  str
#  39  season                   48079 non-null  str
#  40  publish_date_approx      48079 non-null  str
#  41  year_month               48079 non-null  str
#  42  title                    48079 non-null  str
#  43  title_length             48079 non-null  int64
#  44  has_emoji                48079 non-null  int64
#  45  avg_watch_time_sec       48079 non-null  float64
#  46  completion_rate          48079 non-null  float64
#  47  device_brand             48079 non-null  str
#  48  traffic_source           48079 non-null  str
#  49  is_weekend               48079 non-null  int64
#  50  row_id                   48079 non-null  str
#  51  engagement_total         48079 non-null  int64
#  52  like_rate                48079 non-null  float64
#  53  dislike_rate             48079 non-null  float64
#  54  engagement_per_1k        48079 non-null  float64
#  55  engagement_like_rate     48079 non-null  float64
#  56  engagement_comment_rate  48079 non-null  float64
#  57  engagement_share_rate    48079 non-null  float64
# dtypes: float64(15), int64(14), str(29)
# memory usage: 21.3 MB

# %%
df.isnull().sum()
# Out:
# platform                   0
# country                    0
# region                     0
# language                   0
# category                   0
# hashtag                    0
# title_keywords             0
# author_handle              0
# sound_type                 0
# music_track                0
# week_of_year               0
# duration_sec               0
# views                      0
# likes                      0
# comments                   0
# shares                     0
# saves                      0
# engagement_rate            0
# trend_label                0
# source_hint                0
# notes                      0
# device_type                0
# upload_hour                0
# genre                      0
# trend_duration_days        0
# trend_type                 0
# engagement_velocity        0
# dislikes                   0
# comment_ratio              0
# share_rate                 0
# save_rate                  0
# like_dislike_ratio         0
# publish_dayofweek          0
# publish_period             0
# event_season               0
# tags                       0
# sample_comments            0
# creator_avg_views          0
# creator_tier               0
# season                     0
# publish_date_approx        0
# year_month                 0
# title                      0
# title_length               0
# has_emoji                  0
# avg_watch_time_sec         0
# completion_rate            0
# device_brand               0
# traffic_source             0
# is_weekend                 0
# row_id                     0
# engagement_total           0
# like_rate                  0
# dislike_rate               0
# engagement_per_1k          0
# engagement_like_rate       0
# engagement_comment_rate    0
# engagement_share_rate      0
# dtype: int64

# %%
required_for_label = [
    "completion_rate",
    "engagement_velocity",
    "avg_watch_time_sec",
    "duration_sec"
]

for col in required_for_label:
    if col not in df.columns:
        raise ValueError(f"Required column missing: {col}")

# %%
df["completion_rate"] = df["completion_rate"].fillna(
    df["completion_rate"].median()
)

df["engagement_velocity"] = df["engagement_velocity"].fillna(
    df["engagement_velocity"].median()
)

df["avg_watch_time_sec"] = df["avg_watch_time_sec"].fillna(
    df["avg_watch_time_sec"].median()
)

df["duration_sec"] = df["duration_sec"].replace(
    0,
    np.nan
)

df["duration_sec"] = df["duration_sec"].fillna(
    df["duration_sec"].median()
)

# %%
df["watch_ratio"] = (
    df["avg_watch_time_sec"]
    /
    df["duration_sec"]
)

df["watch_ratio"] = df["watch_ratio"].replace(
    [np.inf, -np.inf],
    np.nan
)

df["watch_ratio"] = df["watch_ratio"].fillna(
    df["watch_ratio"].median()
)

# %%
df["completion_rank"] = (
    df["completion_rate"]
    .rank(pct=True)
)

df["engagement_rank"] = (
    df["engagement_velocity"]
    .rank(pct=True)
)

df["watch_ratio_rank"] = (
    df["watch_ratio"]
    .rank(pct=True)
)

# %%
df["viral_score"] = (
      0.45 * df["completion_rank"]
    + 0.40 * df["engagement_rank"]
    + 0.15 * df["watch_ratio_rank"]
)

# %%
cutoff = df["viral_score"].quantile(0.80)

df["trend_label"] = (
    df["viral_score"] >= cutoff
).astype(int)

print(df["trend_label"].value_counts())
# Out:
# trend_label
# 0    38463
# 1     9616
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.countplot(x=df["trend_label"])

plt.title("Viral vs Non-Viral Videos")
plt.xlabel("Trend Label")
plt.ylabel("Count")

plt.show()

# %%
logit_features = [
    "platform",
    "category",
    "duration_sec",
    "completion_rate",
    "engagement_velocity",
    "upload_hour",
    "has_emoji"
]

logit_df = df[
    logit_features + ["trend_label"]
].copy()

# %%
logit_df = logit_df.dropna()

# %%
X_logit = logit_df[logit_features]

y_logit = logit_df["trend_label"]

# %%
categorical_features = [
    "platform",
    "category"
]

# %%
numerical_features = [
    "duration_sec",
    "completion_rate",
    "engagement_velocity",
    "upload_hour",
    "has_emoji"
]

# %%
preprocessor_log = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore"
            ),
            categorical_features
        ),
        (
            "num",
            SimpleImputer(
                strategy="median"
            ),
            numerical_features
        )
    ]
)

# %%
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(
    X_logit,
    y_logit,
    test_size=0.4,
    random_state=98
)

# %%
log_model = Pipeline(
    steps=[
        (
            "preprocess",
            preprocessor_log
        ),
        (
            "model",
            LogisticRegression(
                max_iter=1000
            )
        )
    ]
)

log_model.fit(
    X_train_log,
    y_train_log
)
# Out:
# C:\Users\ANSH SHARMA\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['platform', 'category']),
#                                                  ('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['duration_sec',
#                                                    'completion_rate',
#                                                    'engagement_velocity',
#                                                    'upload_hour',
#                                                    'has_emoji'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
y_pred_log = log_model.predict(
    X_test_log
)

# %%
accuracy = accuracy_score(
    y_test_log,
    y_pred_log
)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8907549916805324

# %%
cm = confusion_matrix(
    y_test_log,
    y_pred_log
)

plt.figure(figsize=(6,4))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.show()

# %%
print(
    classification_report(
        y_test_log,
        y_pred_log
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93     15422
#            1       0.76      0.66      0.71      3810
#
#     accuracy                           0.89     19232
#    macro avg       0.84      0.81      0.82     19232
# weighted avg       0.89      0.89      0.89     19232

# %%
linear_features = [
    "duration_sec",
    "avg_watch_time_sec",
    "platform",
    "category",
    "event_season",
    "traffic_source"
]

linear_features = [
    col for col in linear_features
    if col in df.columns
]

linear_df = df[
    linear_features + ["completion_rate"]
].copy()

linear_df.head()
# Out:
#    duration_sec  avg_watch_time_sec platform category event_season  \
# 0            40                25.8   TikTok   Gaming      Regular
# 1            18                10.4   TikTok     Food      Regular
# 2            22                11.7   TikTok      Art      Regular
# 3            36                23.7   TikTok     News  SummerBreak
# 4            35                24.6   TikTok   Beauty      Regular
#
#   traffic_source  completion_rate
# 0       External            0.645
# 1         Search            0.578
# 2       External            0.532
# 3         Search            0.658
# 4         ForYou            0.703

# %%
linear_df = linear_df.dropna()

print(linear_df.shape)
# Out:
# (48079, 7)

# %%
X_lin = linear_df[linear_features]

y_lin = linear_df["completion_rate"]

# %%
cat_features_lin = [
    "platform",
    "category",
    "event_season",
    "traffic_source"
]

# %%
num_features_lin = [
    "duration_sec",
    "avg_watch_time_sec"
]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

preprocessor_lin = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            cat_features_lin
        ),
        (
            "num",
            SimpleImputer(strategy="median"),
            num_features_lin
        )
    ]
)

# %%
X_train_lin, X_test_lin, y_train_lin, y_test_lin = train_test_split(
    X_lin,
    y_lin,
    test_size=0.4,
    random_state=98
)

# %%
from sklearn.linear_model import LinearRegression

linear_model = Pipeline(
    steps=[
        ("preprocess", preprocessor_lin),
        ("model", LinearRegression())
    ]
)

linear_model.fit(
    X_train_lin,
    y_train_lin
)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['platform', 'category',
#                                                    'event_season',
#                                                    'traffic_source']),
#                                                  ('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['duration_sec',
#                                                    'avg_watch_time_sec'])])),
#                 ('model', LinearRegression())])

# %%
y_pred_lin = linear_model.predict(
    X_test_lin
)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(
    y_test_lin,
    y_pred_lin
)

print("MAE:", mae)
# Out:
# MAE: 0.034963892553197866

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(
    y_test_lin,
    y_pred_lin
)

print("MSE:", mse)
# Out:
# MSE: 0.0021905882771117383

# %%
rmse = np.sqrt(mse)

print("RMSE:", rmse)
# Out:
# RMSE: 0.046803720761406764

# %%
from sklearn.metrics import r2_score

r2 = r2_score(
    y_test_lin,
    y_pred_lin
)

print("R² Score:", r2)
# Out:
# R² Score: 0.8272905686327878

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    y_test_lin,
    y_pred_lin,
    alpha=0.5
)

plt.xlabel("Actual Completion Rate")
plt.ylabel("Predicted Completion Rate")
plt.title("Actual vs Predicted Completion Rate")

plt.show()

# %%
residuals = y_test_lin - y_pred_lin

plt.figure(figsize=(8,5))
plt.scatter(y_pred_lin, residuals, alpha=0.5)

plt.axhline(y=0, linestyle='--')

plt.xlabel("Predicted Completion Rate")
plt.ylabel("Residuals")
plt.title("Residual Plot")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    residuals,
    bins=30
)

plt.xlabel("Residual Error")
plt.ylabel("Frequency")
plt.title("Distribution of Residual Errors")

plt.show()

# %%
print("=== MODEL RESULTS ===")

print(f"Logistic Regression Accuracy: {accuracy:.4f}")

print(f"Linear Regression R2 Score: {r2:.4f}")

print(f"Linear Regression RMSE: {rmse:.4f}")

print("\nConclusion:")
print("The Logistic Regression model successfully predicts viral trends.")
print("The Linear Regression model accurately predicts completion rate.")
print("These models can help Nike optimize future influencer campaigns.")
# Out:
# === MODEL RESULTS ===
# Logistic Regression Accuracy: 0.8908
# Linear Regression R2 Score: 0.8273
# Linear Regression RMSE: 0.0468
#
# Conclusion:
# The Logistic Regression model successfully predicts viral trends.
# The Linear Regression model accurately predicts completion rate.
# These models can help Nike optimize future influencer campaigns.
